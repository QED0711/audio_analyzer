# %%
# %load_ext autoreload
# %autoreload 1

from python.AudioAnalyzer import *
# %aimport python.AudioAnalyzer

# %%
original = AudioAnalyzer("audio/yesterday-original.wav", fft_size=44100, input_sr=44100)
remaster_09 = AudioAnalyzer("audio/yesterday-2009.wav", fft_size=44100, input_sr=44100)
remaster_15 = AudioAnalyzer("audio/yesterday-2015.wav", fft_size=44100, input_sr=44100)

# %%
original.plot_spectrum(min_freq=20, max_freq=1000, title="1965 Original")
remaster_09.plot_spectrum(min_freq=20, max_freq=1000, title="2009 Remaster")
remaster_15.plot_spectrum(min_freq=20, max_freq=1000, title="2015 Remaster")

# %%
orig_to_09 = SignalCompare(original, remaster_09)
orig_to_15 = SignalCompare(original, remaster_15)
remasters = SignalCompare(remaster_09, remaster_15)

# %%
orig_to_09.plot_spectrum_group(frange=(20,1000), ratio=True, threshold=True)
orig_to_09.plot_spectrum_comparison(frange=(20,1000), plot_original=True, cmap='BuPu')

# %%
orig_to_15.plot_spectrum_group(frange=(20,1000), ratio=True, threshold=True)
orig_to_15.plot_spectrum_comparison(frange=(20,1000), plot_original=True, cmap='magma')

# %%
remasters.plot_spectrum_group(frange=(20,1000), ratio=True, threshold=True)
remasters.plot_spectrum_comparison(frange=(20,1000), plot_original=True, cmap='viridis')

# %%
orig_to_09.plot_amplitude_distributions(title="Original vs 09 Remaster")
# Out:
#    T-Statistic  P-Value
# 0  -156.874473      0.0

# %%
orig_to_15.plot_amplitude_distributions(title="Original vs 15 Remaster")
# Out:
#    T-Statistic  P-Value
# 0  -175.016052      0.0

# %%
remasters.plot_amplitude_distributions(title="09 Remaster vs 15 Remaster")
# Out:
#    T-Statistic       P-Value
# 0   -20.040787  1.985208e-81

# %%
equal = SignalCompare(remaster_15, remaster_15)

equal.plot_amplitude_distributions()
# Out:
#    T-Statistic   P-Value
# 0    -0.894408  0.371212
